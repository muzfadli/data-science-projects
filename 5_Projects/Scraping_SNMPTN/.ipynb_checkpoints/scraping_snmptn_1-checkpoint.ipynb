# %% [markdown]
# ### Scraping data from SNMPTN using BeautifoulSoup4

# %% [markdown]
# Get html from https://web.snmptn.ac.id/ptn

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://web.snmptn.ac.id/ptn'
page = requests.get(URL)

soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="id">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>Daftar Perguruan Tinggi dan Program Studi yang Ditawarkan - SNMPTN</title>
# <link href="/favicon.png" rel="shortcut icon"/>
# <link href="/res/css/site.min.css?7e526222325" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700,400italic,700italic|Roboto:400,400italic,700,700italic" rel="stylesheet" type="text/css"/>
# <script src="/res/js/site.min.js?69f56837"></script>
# <script type="text/javascript">
# $(function() {
# 	$('.flash').delay(5000).hide('slow');
# 	$(".navbar i").tooltip({'placement': 'bottom'});
# });
# </script>
# <style type="text/css">
# 	.info-url a { font-size: 90%; color: olivedrab; }
# 	/* make bootstrap tooltip respects newline */
# 	.tooltip-inner { white-space:pre-wrap; }
# 	.ptn-info { color: #444; }
# 	.ptn-info div { margin-bottom: 1px; }
# 	.ptn-info span { font-size: 80%; color: #888; }
# 	.info-url {
#     max-width: 50px;
# 	}
# </style>
# </head>
# <body>
# <div class="navbar navbar-static-top navbar-inverse t-navbar" role="navigation">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target=".navbar-main-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/">SNMPTN</a>
# </div>
# <div class="collapse navbar-collapse navbar-main-collapse">
# <ul class="nav navbar-nav">
# <li><a href="http://www.snmptn.ac.id">Informasi SNMPTN</a></li>
# <li><a href="/ptn">Daftar Program Studi</a></li>
# <li><a href="/portofolio">Portofolio Seni dan Olahraga</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container t-title">
# <h1>Daftar Perguruan Tinggi dan Program Studi yang Ditawarkan</h1>
# </div>
# <!-- HARDCODED RUNNING TEXT
# <marquee class="alert alert-info" behavior="scroll" direction="left">
# 	Pendaftaran dan Finalisasi SNMPTN 2019 diperpanjang sampai SELASA, 19 Februari 2019 pukul 22.00 WIB.
# </marquee>
# -->
# <div class="container t-content">
# <div class="row">
# <div class="col-md-4 col-sm-5">
# <h3>DAFTAR PERGURUAN TINGGI</h3>
# <p class="info">Klik pada nama perguruan tinggi untuk melihat daftar program studi.</p>
# <table class="table table-condensed fancy">
# <tbody>
# <tr>
# <td class="no">1</td>
# <td>
# <a href="/ptn/115" style="font-size:1.1em">ISBI ACEH</a></td></tr></tbody></table></div></div></div></body></html>
# <div class="info-url"><a href="http://pmb.isbiaceh.ac.id/">http://pmb.isbiaceh.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/115">6</a></td>
#
# <tr>
# <td class="no">2</td>
# <td>
# <a href="/ptn/116" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI AR-RANIRY</a></td></tr>
# <div class="info-url"><a href="http://www.pmb.ar-raniry.ac.id/">http://www.pmb.ar-raniry.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/116">17</a></td>
#
# <tr>
# <td class="no">3</td>
# <td>
# <a href="/ptn/112" style="font-size:1.1em">UNIVERSITAS MALIKUSSALEH</a></td></tr>
# <div class="info-url"><a href="http://pmb.unimal.ac.id/">http://pmb.unimal.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/112">32</a></td>
#
# <tr>
# <td class="no">4</td>
# <td>
# <a href="/ptn/114" style="font-size:1.1em">UNIVERSITAS SAMUDRA</a></td></tr>
# <div class="info-url"><a href="https://pmb.unsam.ac.id/">https://pmb.unsam.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/114">25</a></td>
#
# <tr>
# <td class="no">5</td>
# <td>
# <a href="/ptn/111" style="font-size:1.1em">UNIVERSITAS SYIAH KUALA</a></td></tr>
# <div class="info-url"><a href="http://pmb.unsyiah.ac.id/">http://pmb.unsyiah.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/111">63</a></td>
#
# <tr>
# <td class="no">6</td>
# <td>
# <a href="/ptn/113" style="font-size:1.1em">UNIVERSITAS TEUKU UMAR</a></td></tr>
# <div class="info-url"><a href="http://pmb.utu.ac.id/">http://pmb.utu.ac.id/</a></div> <p class="gray">Aceh</p>
#
# <td class="ri"><a href="/ptn/113">20</a></td>
#
# <tr>
# <td class="no">7</td>
# <td>
# <a href="/ptn/123" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI SUMATERA UTARA</a></td></tr>
# <div class="info-url"><a href="http://pmb.uinsu.ac.id/">http://pmb.uinsu.ac.id/</a></div> <p class="gray">Sumatera Utara</p>
#
# <td class="ri"><a href="/ptn/123">10</a></td>
#
# <tr>
# <td class="no">8</td>
# <td>
# <a href="/ptn/122" style="font-size:1.1em">UNIVERSITAS NEGERI MEDAN</a></td></tr>
# <div class="info-url"><a href="http://spmb.unimed.ac.id/">http://spmb.unimed.ac.id/</a></div> <p class="gray">Sumatera Utara</p>
#
# <td class="ri"><a href="/ptn/122">51</a></td>
#
# <tr>
# <td class="no">9</td>
# <td>
# <a href="/ptn/121" style="font-size:1.1em">UNIVERSITAS SUMATERA UTARA</a></td></tr>
# <div class="info-url"><a href="https://penerimaan.usu.ac.id/">https://penerimaan.usu.ac.id/</a></div> <p class="gray">Sumatera Utara</p>
#
# <td class="ri"><a href="/ptn/121">47</a></td>
#
# <tr>
# <td class="no">10</td>
# <td>
# <a href="/ptn/143" style="font-size:1.1em">ISI PADANG PANJANG</a></td></tr>
# <div class="info-url"><a href="https://www.isi-padangpanjang.ac.id">https://www.isi-padangpanjang.ac.id</a></div> <p class="gray">Sumatera Barat</p>
#
# <td class="ri"><a href="/ptn/143">11</a></td>
#
# <tr>
# <td class="no">11</td>
# <td>
# <a href="/ptn/141" style="font-size:1.1em">UNIVERSITAS ANDALAS</a></td></tr>
# <div class="info-url"><a href="https://pmb.unand.ac.id/">https://pmb.unand.ac.id/</a></div> <p class="gray">Sumatera Barat</p>
#
# <td class="ri"><a href="/ptn/141">47</a></td>
#
# <tr>
# <td class="no">12</td>
# <td>
# <a href="/ptn/142" style="font-size:1.1em">UNIVERSITAS NEGERI PADANG</a></td></tr>
# <div class="info-url"><a href="http://spmb.unp.ac.id/">http://spmb.unp.ac.id/</a></div> <p class="gray">Sumatera Barat</p>
#
# <td class="ri"><a href="/ptn/142">56</a></td>
#
# <tr>
# <td class="no">13</td>
# <td>
# <a href="/ptn/132" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI SULTAN SYARIF KASIM</a></td></tr>
# <div class="info-url"><a href="http://pmb.uin-suska.ac.id/">http://pmb.uin-suska.ac.id/</a></div> <p class="gray">Riau</p>
#
# <td class="ri"><a href="/ptn/132">19</a></td>
#
# <tr>
# <td class="no">14</td>
# <td>
# <a href="/ptn/131" style="font-size:1.1em">UNIVERSITAS RIAU</a></td></tr>
# <div class="info-url"><a href="https://pmb.unri.ac.id/">https://pmb.unri.ac.id/</a></div> <p class="gray">Riau</p>
#
# <td class="ri"><a href="/ptn/131">53</a></td>
#
# <tr>
# <td class="no">15</td>
# <td>
# <a href="/ptn/133" style="font-size:1.1em">UNIVERSITAS MARITIM RAJA ALI HAJI</a></td></tr>
# <div class="info-url"><a href="https://penerimaan.umrah.ac.id/">https://penerimaan.umrah.ac.id/</a></div> <p class="gray">Kepulauan Riau</p>
#
# <td class="ri"><a href="/ptn/133">20</a></td>
#
# <tr>
# <td class="no">16</td>
# <td>
# <a href="/ptn/151" style="font-size:1.1em">UNIVERSITAS JAMBI</a></td></tr>
# <div class="info-url"><a href="https://pmb.unja.ac.id/">https://pmb.unja.ac.id/</a></div> <p class="gray">Jambi</p>
#
# <td class="ri"><a href="/ptn/151">52</a></td>
#
# <tr>
# <td class="no">17</td>
# <td>
# <a href="/ptn/161" style="font-size:1.1em">UNIVERSITAS BENGKULU</a></td></tr>
# <div class="info-url"><a href="http://admisi.unib.ac.id/">http://admisi.unib.ac.id/</a></div> <p class="gray">Bengkulu</p>
#
# <td class="ri"><a href="/ptn/161">44</a></td>
#
# <tr>
# <td class="no">18</td>
# <td>
# <a href="/ptn/172" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI RADEN FATAH</a></td></tr>
# <div class="info-url"><a href="http://pmb.radenfatah.ac.id/">http://pmb.radenfatah.ac.id/</a></div> <p class="gray">Sumatera Selatan</p>
#
# <td class="ri"><a href="/ptn/172">9</a></td>
#
# <tr>
# <td class="no">19</td>
# <td>
# <a href="/ptn/171" style="font-size:1.1em">UNIVERSITAS SRIWIJAYA</a></td></tr>
# <div class="info-url"><a href="https://reg.unsri.ac.id/">https://reg.unsri.ac.id/</a></div> <p class="gray">Sumatera Selatan</p>
#
# <td class="ri"><a href="/ptn/171">56</a></td>
#
# <tr>
# <td class="no">20</td>
# <td>
# <a href="/ptn/181" style="font-size:1.1em">UNIVERSITAS BANGKA BELITUNG</a></td></tr>
# <div class="info-url"><a href="http://pmb.ubb.ac.id/">http://pmb.ubb.ac.id/</a></div> <p class="gray">Kepulauan Bangka Belitung</p>
#
# <td class="ri"><a href="/ptn/181">20</a></td>
#
# <tr>
# <td class="no">21</td>
# <td>
# <a href="/ptn/192" style="font-size:1.1em">INSTITUT TEKNOLOGI SUMATERA</a></td></tr>
# <div class="info-url"><a href="https://pmb.itera.ac.id/">https://pmb.itera.ac.id/</a></div> <p class="gray">Lampung</p>
#
# <td class="ri"><a href="/ptn/192">33</a></td>
#
# <tr>
# <td class="no">22</td>
# <td>
# <a href="/ptn/191" style="font-size:1.1em">UNIVERSITAS LAMPUNG</a></td></tr>
# <div class="info-url"><a href="http://simanila.unila.ac.id/">http://simanila.unila.ac.id/</a></div> <p class="gray">Lampung</p>
#
# <td class="ri"><a href="/ptn/191">59</a></td>
#
# <tr>
# <td class="no">23</td>
# <td>
# <a href="/ptn/321" style="font-size:1.1em">UNIVERSITAS INDONESIA</a></td></tr>
# <div class="info-url"><a href="https://penerimaan.ui.ac.id/">https://penerimaan.ui.ac.id/</a></div> <p class="gray">DKI Jakarta</p>
#
# <td class="ri"><a href="/ptn/321">64</a></td>
#
# <tr>
# <td class="no">24</td>
# <td>
# <a href="/ptn/322" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI JAKARTA</a></td></tr>
# <div class="info-url"><a href="https://spmb.uinjkt.ac.id/">https://spmb.uinjkt.ac.id/</a></div> <p class="gray">DKI Jakarta</p>
#
# <td class="ri"><a href="/ptn/322">26</a></td>
#
# <tr>
# <td class="no">25</td>
# <td>
# <a href="/ptn/323" style="font-size:1.1em">UNIVERSITAS NEGERI JAKARTA</a></td></tr>
# <div class="info-url"><a href="http://penmaba.unj.ac.id/">http://penmaba.unj.ac.id/</a></div> <p class="gray">DKI Jakarta</p>
#
# <td class="ri"><a href="/ptn/323">60</a></td>
#
# <tr>
# <td class="no">26</td>
# <td>
# <a href="/ptn/329" style="font-size:1.1em">UNIVERSITAS TERBUKA</a></td></tr>
# <div class="info-url"><a href="https://www.ut.ac.id/sistem-registrasi">https://www.ut.ac.id/sistem-registrasi</a></div> <p class="gray">DKI Jakarta</p>
#
# <td class="ri"><a href="/ptn/329">2</a></td>
#
# <tr>
# <td class="no">27</td>
# <td>
# <a href="/ptn/324" style="font-size:1.1em">UPN "VETERAN" JAKARTA</a></td></tr>
# <div class="info-url"><a href="https://penmaru.upnvj.ac.id/">https://penmaru.upnvj.ac.id/</a></div> <p class="gray">DKI Jakarta</p>
#
# <td class="ri"><a href="/ptn/324">19</a></td>
#
# <tr>
# <td class="no">28</td>
# <td>
# <a href="/ptn/341" style="font-size:1.1em">INSTITUT PERTANIAN BOGOR</a></td></tr>
# <div class="info-url"><a href="https://admisi.ipb.ac.id/">https://admisi.ipb.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/341">39</a></td>
#
# <tr>
# <td class="no">29</td>
# <td>
# <a href="/ptn/332" style="font-size:1.1em">INSTITUT TEKNOLOGI BANDUNG</a></td></tr>
# <div class="info-url"><a href="https://usm.itb.ac.id/">https://usm.itb.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/332">20</a></td>
#
# <tr>
# <td class="no">30</td>
# <td>
# <a href="/ptn/335" style="font-size:1.1em">ISBI BANDUNG</a></td></tr>
# <div class="info-url"><a href="https://pmb.isbi.ac.id/">https://pmb.isbi.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/335">5</a></td>
#
# <tr>
# <td class="no">31</td>
# <td>
# <a href="/ptn/336" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI SUNAN GUNUNG DJATI</a></td></tr>
# <div class="info-url"><a href="https://pmb.uinsgd.ac.id/">https://pmb.uinsgd.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/336">16</a></td>
#
# <tr>
# <td class="no">32</td>
# <td>
# <a href="/ptn/333" style="font-size:1.1em">UNIVERSITAS PADJADJARAN</a></td></tr>
# <div class="info-url"><a href="http://smup.unpad.ac.id/">http://smup.unpad.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/333">58</a></td>
#
# <tr>
# <td class="no">33</td>
# <td>
# <a href="/ptn/334" style="font-size:1.1em">UNIVERSITAS PENDIDIKAN INDONESIA</a></td></tr>
# <div class="info-url"><a href="https://pmb.upi.edu/">https://pmb.upi.edu/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/334">90</a></td>
#
# <tr>
# <td class="no">34</td>
# <td>
# <a href="/ptn/342" style="font-size:1.1em">UNIVERSITAS SILIWANGI</a></td></tr>
# <div class="info-url"><a href="https://pmb.unsil.ac.id/">https://pmb.unsil.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/342">22</a></td>
#
# <tr>
# <td class="no">35</td>
# <td>
# <a href="/ptn/331" style="font-size:1.1em">UNIVERSITAS SINGAPERBANGSA KARAWANG</a></td></tr>
# <div class="info-url"><a href="https://pmb.unsika.ac.id/">https://pmb.unsika.ac.id/</a></div> <p class="gray">Jawa Barat</p>
#
# <td class="ri"><a href="/ptn/331">22</a></td>
#
# <tr>
# <td class="no">36</td>
# <td>
# <a href="/ptn/354" style="font-size:1.1em">ISI SURAKARTA</a></td></tr>
# <div class="info-url"><a href="https://spmb.isi-ska.ac.id/">https://spmb.isi-ska.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/354">11</a></td>
#
# <tr>
# <td class="no">37</td>
# <td>
# <a href="/ptn/355" style="font-size:1.1em">UNIVERSITAS DIPONEGORO</a></td></tr>
# <div class="info-url"><a href="https://um.undip.ac.id/">https://um.undip.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/355">52</a></td>
#
# <tr>
# <td class="no">38</td>
# <td>
# <a href="/ptn/357" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI WALISONGO</a></td></tr>
# <div class="info-url"><a href="http://pmb.walisongo.ac.id/">http://pmb.walisongo.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/357">11</a></td>
#
# <tr>
# <td class="no">39</td>
# <td>
# <a href="/ptn/351" style="font-size:1.1em">UNIVERSITAS JENDERAL SOEDIRMAN</a></td></tr>
# <div class="info-url"><a href="http://spmb.unsoed.ac.id/">http://spmb.unsoed.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/351">39</a></td>
#
# <tr>
# <td class="no">40</td>
# <td>
# <a href="/ptn/356" style="font-size:1.1em">UNIVERSITAS NEGERI SEMARANG</a></td></tr>
# <div class="info-url"><a href="http://penerimaan.unnes.ac.id">http://penerimaan.unnes.ac.id</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/356">69</a></td>
#
# <tr>
# <td class="no">41</td>
# <td>
# <a href="/ptn/353" style="font-size:1.1em">UNIVERSITAS SEBELAS MARET</a></td></tr>
# <div class="info-url"><a href="https://spmb.uns.ac.id/">https://spmb.uns.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/353">67</a></td>
#
# <tr>
# <td class="no">42</td>
# <td>
# <a href="/ptn/352" style="font-size:1.1em">UNIVERSITAS TIDAR</a></td></tr>
# <div class="info-url"><a href="https://um.untidar.ac.id/">https://um.untidar.ac.id/</a></div> <p class="gray">Jawa Tengah</p>
#
# <td class="ri"><a href="/ptn/352">17</a></td>
#
# <tr>
# <td class="no">43</td>
# <td>
# <a href="/ptn/364" style="font-size:1.1em">ISI YOGYAKARTA</a></td></tr>
# <div class="info-url"><a href="https://pmb.isi.ac.id/">https://pmb.isi.ac.id/</a></div> <p class="gray">DI Yogyakarta</p>
#
# <td class="ri"><a href="/ptn/364">17</a></td>
#
# <tr>
# <td class="no">44</td>
# <td>
# <a href="/ptn/361" style="font-size:1.1em">UNIVERSITAS GADJAH MADA</a></td></tr>
# <div class="info-url"><a href="https://um.ugm.ac.id/">https://um.ugm.ac.id/</a></div> <p class="gray">DI Yogyakarta</p>
#
# <td class="ri"><a href="/ptn/361">69</a></td>
#
# <tr>
# <td class="no">45</td>
# <td>
# <a href="/ptn/365" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI SUNAN KALIJAGA</a></td></tr>
# <div class="info-url"><a href="https://admisi.uin-suka.ac.id/">https://admisi.uin-suka.ac.id/</a></div> <p class="gray">DI Yogyakarta</p>
#
# <td class="ri"><a href="/ptn/365">17</a></td>
#
# <tr>
# <td class="no">46</td>
# <td>
# <a href="/ptn/362" style="font-size:1.1em">UNIVERSITAS NEGERI YOGYAKARTA</a></td></tr>
# <div class="info-url"><a href="http://pmb.uny.ac.id/">http://pmb.uny.ac.id/</a></div> <p class="gray">DI Yogyakarta</p>
#
# <td class="ri"><a href="/ptn/362">60</a></td>
#
# <tr>
# <td class="no">47</td>
# <td>
# <a href="/ptn/363" style="font-size:1.1em">UPN "VETERAN" YOGYAKARTA</a></td></tr>
# <div class="info-url"><a href="http://pmb.upnyk.ac.id/">http://pmb.upnyk.ac.id/</a></div> <p class="gray">DI Yogyakarta</p>
#
# <td class="ri"><a href="/ptn/363">21</a></td>
#
# <tr>
# <td class="no">48</td>
# <td>
# <a href="/ptn/382" style="font-size:1.1em">INSTITUT TEKNOLOGI SEPULUH NOPEMBER</a></td></tr>
# <div class="info-url"><a href="https://smits.its.ac.id/">https://smits.its.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/382">33</a></td>
#
# <tr>
# <td class="no">49</td>
# <td>
# <a href="/ptn/381" style="font-size:1.1em">UNIVERSITAS AIRLANGGA</a></td></tr>
# <div class="info-url"><a href="http://ppmb.unair.ac.id">http://ppmb.unair.ac.id</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/381">44</a></td>
#
# <tr>
# <td class="no">50</td>
# <td>
# <a href="/ptn/372" style="font-size:1.1em">UNIVERSITAS BRAWIJAYA</a></td></tr>
# <div class="info-url"><a href="https://selma.ub.ac.id/">https://selma.ub.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/372">77</a></td>
#
# <tr>
# <td class="no">51</td>
# <td>
# <a href="/ptn/374" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI MALANG</a></td></tr>
# <div class="info-url"><a href="http://pmb.uin-malang.ac.id/">http://pmb.uin-malang.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/374">14</a></td>
#
# <tr>
# <td class="no">52</td>
# <td>
# <a href="/ptn/386" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI SUNAN AMPEL SURABAYA</a></td></tr>
# <div class="info-url"><a href="https://www.uinsby.ac.id/">https://www.uinsby.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/386">20</a></td>
#
# <tr>
# <td class="no">53</td>
# <td>
# <a href="/ptn/371" style="font-size:1.1em">UNIVERSITAS JEMBER</a></td></tr>
# <div class="info-url"><a href="https://unej.ac.id/pendaftaran/">https://unej.ac.id/pendaftaran/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/371">61</a></td>
#
# <tr>
# <td class="no">54</td>
# <td>
# <a href="/ptn/373" style="font-size:1.1em">UNIVERSITAS NEGERI MALANG</a></td></tr>
# <div class="info-url"><a href="https://um.ac.id/akademik/seleksi-mahasiswa/jalur-seleksi-masuk/">https://um.ac.id/akademik/seleksi-mahasiswa/jalur-seleksi-masuk/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/373">59</a></td>
#
# <tr>
# <td class="no">55</td>
# <td>
# <a href="/ptn/383" style="font-size:1.1em">UNIVERSITAS NEGERI SURABAYA</a></td></tr>
# <div class="info-url"><a href="https://sipenmaru.unesa.ac.id/">https://sipenmaru.unesa.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/383">63</a></td>
#
# <tr>
# <td class="no">56</td>
# <td>
# <a href="/ptn/384" style="font-size:1.1em">UNIVERSITAS TRUNOJOYO MADURA</a></td></tr>
# <div class="info-url"><a href="https://pmb.trunojoyo.ac.id/">https://pmb.trunojoyo.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/384">26</a></td>
#
# <tr>
# <td class="no">57</td>
# <td>
# <a href="/ptn/385" style="font-size:1.1em">UPN "VETERAN" JAWA TIMUR</a></td></tr>
# <div class="info-url"><a href="https://simaba.upnjatim.ac.id/">https://simaba.upnjatim.ac.id/</a></div> <p class="gray">Jawa Timur</p>
#
# <td class="ri"><a href="/ptn/385">19</a></td>
#
# <tr>
# <td class="no">58</td>
# <td>
# <a href="/ptn/311" style="font-size:1.1em">UNIVERSITAS SULTAN AGENG TIRTAYASA</a></td></tr>
# <div class="info-url"><a href="http://spmb.untirta.ac.id/">http://spmb.untirta.ac.id/</a></div> <p class="gray">Banten</p>
#
# <td class="ri"><a href="/ptn/311">39</a></td>
#
# <tr>
# <td class="no">59</td>
# <td>
# <a href="/ptn/613" style="font-size:1.1em">ISI DENPASAR</a></td></tr>
# <div class="info-url"><a href="https://spmb.isi-dps.ac.id/">https://spmb.isi-dps.ac.id/</a></div> <p class="gray">Bali</p>
#
# <td class="ri"><a href="/ptn/613">10</a></td>
#
# <tr>
# <td class="no">60</td>
# <td>
# <a href="/ptn/612" style="font-size:1.1em">UNIVERSITAS PENDIDIKAN GANESHA</a></td></tr>
# <div class="info-url"><a href="https://undiksha.ac.id/tag/pmb-undiksha/">https://undiksha.ac.id/tag/pmb-undiksha/</a></div> <p class="gray">Bali</p>
#
# <td class="ri"><a href="/ptn/612">37</a></td>
#
# <tr>
# <td class="no">61</td>
# <td>
# <a href="/ptn/611" style="font-size:1.1em">UNIVERSITAS UDAYANA</a></td></tr>
# <div class="info-url"><a href="https://e-registrasi.unud.ac.id/">https://e-registrasi.unud.ac.id/</a></div> <p class="gray">Bali</p>
#
# <td class="ri"><a href="/ptn/611">48</a></td>
#
# <tr>
# <td class="no">62</td>
# <td>
# <a href="/ptn/621" style="font-size:1.1em">UNIVERSITAS MATARAM</a></td></tr>
# <div class="info-url"><a href="https://pmb.unram.ac.id/">https://pmb.unram.ac.id/</a></div> <p class="gray">Nusa Tenggara Barat</p>
#
# <td class="ri"><a href="/ptn/621">38</a></td>
#
# <tr>
# <td class="no">63</td>
# <td>
# <a href="/ptn/631" style="font-size:1.1em">UNIVERSITAS NUSA CENDANA</a></td></tr>
# <div class="info-url"><a href="https://undana.ac.id/admissions/ssm-ptn/">https://undana.ac.id/admissions/ssm-ptn/</a></div> <p class="gray">Nusa Tenggara Timur</p>
#
# <td class="ri"><a href="/ptn/631">47</a></td>
#
# <tr>
# <td class="no">64</td>
# <td>
# <a href="/ptn/632" style="font-size:1.1em">UNIVERSITAS TIMOR</a></td></tr>
# <div class="info-url"><a href="https://www.unimor.ac.id/pendaftaran-snmptn/">https://www.unimor.ac.id/pendaftaran-snmptn/</a></div> <p class="gray">Nusa Tenggara Timur</p>
#
# <td class="ri"><a href="/ptn/632">15</a></td>
#
# <tr>
# <td class="no">65</td>
# <td>
# <a href="/ptn/511" style="font-size:1.1em">UNIVERSITAS TANJUNGPURA</a></td></tr>
# <div class="info-url"><a href="http://scmb.untan.ac.id/">http://scmb.untan.ac.id/</a></div> <p class="gray">Kalimantan Barat</p>
#
# <td class="ri"><a href="/ptn/511">64</a></td>
#
# <tr>
# <td class="no">66</td>
# <td>
# <a href="/ptn/521" style="font-size:1.1em">UNIVERSITAS PALANGKARAYA</a></td></tr>
# <div class="info-url"><a href="http://www.upr.ac.id">http://www.upr.ac.id</a></div> <p class="gray">Kalimantan Tengah</p>
#
# <td class="ri"><a href="/ptn/521">41</a></td>
#
# <tr>
# <td class="no">67</td>
# <td>
# <a href="/ptn/531" style="font-size:1.1em">UNIVERSITAS LAMBUNG MANGKURAT</a></td></tr>
# <div class="info-url"><a href="https://ulm.ac.id/id/category/penerimaan-mahasiswa-baru/">https://ulm.ac.id/id/category/penerimaan-mahasiswa-baru/</a></div> <p class="gray">Kalimantan Selatan</p>
#
# <td class="ri"><a href="/ptn/531">64</a></td>
#
# <tr>
# <td class="no">68</td>
# <td>
# <a href="/ptn/542" style="font-size:1.1em">INSTITUT TEKNOLOGI KALIMANTAN</a></td></tr>
# <div class="info-url"><a href="https://itk.ac.id/pendaftaran/">https://itk.ac.id/pendaftaran/</a></div> <p class="gray">Kalimantan Timur</p>
#
# <td class="ri"><a href="/ptn/542">14</a></td>
#
# <tr>
# <td class="no">69</td>
# <td>
# <a href="/ptn/541" style="font-size:1.1em">UNIVERSITAS MULAWARMAN</a></td></tr>
# <div class="info-url"><a href="https://unmul.ac.id/page/pendaftaran-sarjana-1486971670.html">https://unmul.ac.id/page/pendaftaran-sarjana-1486971670.html</a></div> <p class="gray">Kalimantan Timur</p>
#
# <td class="ri"><a href="/ptn/541">61</a></td>
#
# <tr>
# <td class="no">70</td>
# <td>
# <a href="/ptn/551" style="font-size:1.1em">UNIVERSITAS BORNEO TARAKAN</a></td></tr>
# <div class="info-url"><a href="https://pmb.borneo.ac.id/">https://pmb.borneo.ac.id/</a></div> <p class="gray">Kalimantan Utara</p>
#
# <td class="ri"><a href="/ptn/551">19</a></td>
#
# <tr>
# <td class="no">71</td>
# <td>
# <a href="/ptn/722" style="font-size:1.1em">UNIVERSITAS NEGERI MANADO</a></td></tr>
# <div class="info-url"><a href="https://penerimaan.unima.ac.id/">https://penerimaan.unima.ac.id/</a></div> <p class="gray">Sulawesi Utara</p>
#
# <td class="ri"><a href="/ptn/722">47</a></td>
#
# <tr>
# <td class="no">72</td>
# <td>
# <a href="/ptn/721" style="font-size:1.1em">UNIVERSITAS SAM RATULANGI</a></td></tr>
# <div class="info-url"><a href="https://www.unsrat.ac.id/Seleksi_Masuk/jalur_masuk">https://www.unsrat.ac.id/Seleksi_Masuk/jalur_masuk</a></div> <p class="gray">Sulawesi Utara</p>
#
# <td class="ri"><a href="/ptn/721">48</a></td>
#
# <tr>
# <td class="no">73</td>
# <td>
# <a href="/ptn/731" style="font-size:1.1em">UNIVERSITAS TADULAKO</a></td></tr>
# <div class="info-url"><a href="https://pmb.untad.ac.id/">https://pmb.untad.ac.id/</a></div> <p class="gray">Sulawesi Tengah</p>
#
# <td class="ri"><a href="/ptn/731">51</a></td>
#
# <tr>
# <td class="no">74</td>
# <td>
# <a href="/ptn/711" style="font-size:1.1em">UNIVERSITAS HASANUDDIN</a></td></tr>
# <div class="info-url"><a href="https://unhas.ac.id/pmb/">https://unhas.ac.id/pmb/</a></div> <p class="gray">Sulawesi Selatan</p>
#
# <td class="ri"><a href="/ptn/711">62</a></td>
#
# <tr>
# <td class="no">75</td>
# <td>
# <a href="/ptn/713" style="font-size:1.1em">UNIVERSITAS ISLAM NEGERI ALAUDDIN</a></td></tr>
# <div class="info-url"><a href="http://pmb.uin-alauddin.ac.id/site/login">http://pmb.uin-alauddin.ac.id/site/login</a></div> <p class="gray">Sulawesi Selatan</p>
#
# <td class="ri"><a href="/ptn/713">16</a></td>
#
# <tr>
# <td class="no">76</td>
# <td>
# <a href="/ptn/712" style="font-size:1.1em">UNIVERSITAS NEGERI MAKASSAR</a></td></tr>
# <div class="info-url"><a href="http://pmbm.unm.ac.id/">http://pmbm.unm.ac.id/</a></div> <p class="gray">Sulawesi Selatan</p>
#
# <td class="ri"><a href="/ptn/712">73</a></td>
#
# <tr>
# <td class="no">77</td>
# <td>
# <a href="/ptn/751" style="font-size:1.1em">UNIVERSITAS HALUOLEO</a></td></tr>
# <div class="info-url"><a href="https://www.uho.ac.id/">https://www.uho.ac.id/</a></div> <p class="gray">Sulawesi Tenggara</p>
#
# <td class="ri"><a href="/ptn/751">75</a></td>
#
# <tr>
# <td class="no">78</td>
# <td>
# <a href="/ptn/753" style="font-size:1.1em">UNIVERSITAS SEMBILAN BELAS NOVEMBER KOLAKA</a></td></tr>
# <div class="info-url"><a href="https://pmb.usn.ac.id/">https://pmb.usn.ac.id/</a></div> <p class="gray">Sulawesi Tenggara</p>
#
# <td class="ri"><a href="/ptn/753">29</a></td>
#
# <tr>
# <td class="no">79</td>
# <td>
# <a href="/ptn/752" style="font-size:1.1em">UNIVERSITAS NEGERI GORONTALO</a></td></tr>
# <div class="info-url"><a href="http://pmb.ung.ac.id/">http://pmb.ung.ac.id/</a></div> <p class="gray">Gorontalo</p>
#
# <td class="ri"><a href="/ptn/752">52</a></td>
#
# <tr>
# <td class="no">80</td>
# <td>
# <a href="/ptn/741" style="font-size:1.1em">UNIVERSITAS SULAWESI BARAT</a></td></tr>
# <div class="info-url"><a href="https://unsulbar.ac.id/">https://unsulbar.ac.id/</a></div> <p class="gray">Sulawesi Barat</p>
#
# <td class="ri"><a href="/ptn/741">20</a></td>
#
# <tr>
# <td class="no">81</td>
# <td>
# <a href="/ptn/811" style="font-size:1.1em">UNIVERSITAS PATTIMURA</a></td></tr>
# <div class="info-url"><a href="https://pmb.unpatti.ac.id">https://pmb.unpatti.ac.id</a></div> <p class="gray">Maluku</p>
#
# <td class="ri"><a href="/ptn/811">65</a></td>
#
# <tr>
# <td class="no">82</td>
# <td>
# <a href="/ptn/821" style="font-size:1.1em">UNIVERSITAS KHAIRUN</a></td></tr>
# <div class="info-url"><a href="http://pmb.unkhair.ac.id/">http://pmb.unkhair.ac.id/</a></div> <p class="gray">Maluku Utara</p>
#
# <td class="ri"><a href="/ptn/821">35</a></td>
#
# <tr>
# <td class="no">83</td>
# <td>
# <a href="/ptn/913" style="font-size:1.1em">ISBI TANAH PAPUA</a></td></tr>
# <div class="info-url"><a href="http://isbi-tanahpapua.ac.id/">http://isbi-tanahpapua.ac.id/</a></div> <p class="gray">Papua</p>
#
# <td class="ri"><a href="/ptn/913">5</a></td>
#
# <tr>
# <td class="no">84</td>
# <td>
# <a href="/ptn/911" style="font-size:1.1em">UNIVERSITAS CENDERAWASIH</a></td></tr>
# <div class="info-url"><a href="https://www.uncen.ac.id/registrasi/">https://www.uncen.ac.id/registrasi/</a></div> <p class="gray">Papua</p>
#
# <td class="ri"><a href="/ptn/911">44</a></td>
#
# <tr>
# <td class="no">85</td>
# <td>
# <a href="/ptn/912" style="font-size:1.1em">UNIVERSITAS MUSAMUS MERAUKE</a></td></tr>
# <div class="info-url"><a href="http://www.unmus.ac.id/">http://www.unmus.ac.id/</a></div> <p class="gray">Papua</p>
#
# <td class="ri"><a href="/ptn/912">25</a></td>
#
# <tr>
# <td class="no">86</td>
# <td>
# <a href="/ptn/921" style="font-size:1.1em">UNIVERSITAS PAPUA</a></td></tr>
# <div class="info-url"><a href="https://bpak.unipa.ac.id/">https://bpak.unipa.ac.id/</a></div> <p class="gray">Papua Barat</p>
#
# <td class="ri"><a href="/ptn/921">30</a></td>
#
#
#
#
# <div class="col-md-8 col-sm-7">
# </div>
#
#
# <div class="container t-footer">
# <div class="row">
# <div class="col-md-12">
# <img alt="Smiley face" src="/res/img/ltmpt.jpg"/>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <img height="46" src="/res/img/telkom.png"/>
# <img height="26" src="/res/img/mandiri.png"/>
# <img height="26" src="/res/img/bni.png"/>
# <img height="20" src="/res/img/btn.png"/>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <p>© 2012 - 2020</p>
# </div>
# </div>
# <label style="font-size: 6px; font-weight: normal; font-variant: small-caps;">frontend-26</label> </div>
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-72479844-2', 'auto');
#   ga('send', 'pageview');
#
#
#
#
#
# 	ga('send', {
# 	  hitType: 'event',
# 	  eventCategory: 'Server Akses',
# 	  eventAction: 'Server frontend-26',
# 	  eventLabel: 'Server frontend-26'
# 	});
#
#
# </script>

# %% [markdown]
# get university data

# %%
def scrape_univ_snmptn(snmptn_url):
    page = requests.get(snmptn_url)

    univ = BeautifulSoup(page.content, 'html.parser')

    universities = univ.find_all('tr')
    list_univ = []
    for i in range(0, len(universities)):
        dict_university = {}
        dict_university['univId'] = universities[i].find('a')['href'][5:]
        dict_university['univ_name'] = universities[i].find('a').text
        dict_university['url'] = 'https://web.snmptn.ac.id' + universities[i].find('a')['href']
        list_univ.append(dict_university)
        
    return list_univ

# %%
snmptn_url = 'https://web.snmptn.ac.id/ptn'
list_univ = scrape_univ_snmptn(snmptn_url)

# %% [markdown]
# get prodi data

# %%
def scrape_prodi(url_ptn):
    page = requests.get(url_ptn)

    ptn_soup = BeautifulSoup(page.content, 'html.parser')

    univ_prodi = []
    url = 'https://web.snmptn.ac.id'
    try:
        # Prodi SAINTEK
        saintek = ptn_soup.find(id='cat-SAINTEK')
        prodi_saintek = saintek.find_all('tr')
        for i in range(1,len(prodi_saintek)):
            prodi = {}
            prod = prodi_saintek[i].find_all('td')
            prodi['kode_prodi'] = prod[1].text
            prodi['nama_prodi'] = prod[2].text
            prodi['url_prodi'] = url + prodi_saintek[i].find('a')['href']
            prodi['jenis'] = 'SAINTEK'
            prodi['daya_tampung'] = prod[3].text
            univ_prodi.append(prodi)
    except:
        pass

    try:
        # Prodi SOSHUM
        soshum = ptn_soup.find(id='cat-SOSHUM')
        prodi_soshum = soshum.find_all('tr')
        for j in range(1,len(prodi_soshum)):
            prodi = {}
            prod = prodi_soshum[j].find_all('td')
            prodi['kode_prodi'] = prod[1].text
            prodi['nama_prodi'] = prod[2].text
            prodi['url_prodi'] = url + prodi_soshum[j].find('a')['href']
            prodi['jenis'] = 'SOSHUM'
            prodi['daya_tampung'] = prod[3].text
            univ_prodi.append(prodi)
    except:
        pass
    
    return univ_prodi

# %%
ptn = 'https://web.snmptn.ac.id/ptn/112'
univ_prodi = scrape_prodi(ptn)

# %% [markdown]
# get prodi detail

# %%
def get_prodi_detail(url):
    page = requests.get(url)
    prodi_soup = BeautifulSoup(page.content, 'html.parser')
    # detail prodi
    detail = prodi_soup.find_all('div', class_='panel panel-info')
    daya_tampung = detail[0].find_all('td')[1].text
    jenis = detail[0].find_all('td')[3].text
    if len(detail)==4:
        try:
            portfolio = detail[1].find('td').text
        except:
            portfolio = ''
        k = 2
    else:
        portfolio = ''
        k = 1
    jur = detail[k].find_all('td')
    jurusan_pendaftar = []
    for i in range(0,len(jur)):
        jurusan_pendaftar.append(jur[i].text)

    sebaran = detail[k+1].find_all('tr')
    # tahun sebaran
    tahun_sebaran = sebaran[0].find_all('th', class_='ce')
    tahun = []
    for th in range(0,len(tahun_sebaran)):
        tahun.append(tahun_sebaran[th].text)
    # jumlah pendaftar dan diterima
    jumlah_pendaftar = []
    jumlah_diterima = []
    jumlah_siswa_jur = []
    jumlah_siswa_prov = []
    for pend in range(0,len(tahun)):
        jumlah_pendaftar.append({str(tahun[pend]):sebaran[1].find_all('td', class_='ce')[pend].text})
        jumlah_diterima.append({str(tahun[pend]):sebaran[2].find_all('td', class_='ce')[pend].text.split('(')[0]})

    for i in sebaran[3:]:
        g = i.find_all('td')
        if len(g) == 2+len(tahun):
            nama_jur = {}
            list_angka_tahun = {}
            for pend in range(0,len(tahun)):
                list_angka_tahun[str(tahun[pend])]=g[pend+2].text
                nama_jur[str(g[0].text) + ' ' + str(g[1].text)] = list_angka_tahun
            jumlah_siswa_jur.append(nama_jur)

        elif len(g) == 1+len(tahun):
            nama_prov = {}
            list_angka_th = {}
            for pend in range(0,len(tahun)):
                list_angka_th[str(tahun[pend])]=g[pend+1].text
            nama_prov[str(g[0].text)] = list_angka_th
            jumlah_siswa_prov.append(nama_prov)

    detail_prodi = {
        'daya_tampung': daya_tampung,
        'jenis': jenis,
        'jurusan_pendaftar': jurusan_pendaftar,
        'jumlah_pendaftar': jumlah_pendaftar,
        'jumlah_diterima': jumlah_diterima,
        'jumlah_diterima_berdasarkan_jur': jumlah_siswa_jur,
        'jumlah_siswa_diterima_berdasarkan_provinsi': jumlah_siswa_prov
    }
    
    return detail_prodi

# %%
url = 'https://web.snmptn.ac.id/ptn/112/20551'
prodi_detail = get_prodi_detail(url)

# %% [markdown]
# get all

# %%
snmptn_url = 'https://web.snmptn.ac.id/ptn'
list_univ = scrape_univ_snmptn(snmptn_url)

data_snmptn = []
for i in list_univ:
    univ_prodi = scrape_prodi(i['url'])
    for j in univ_prodi:
        data = {}
        data.update(i)
        data.update(j)
        data['detail_prodi'] = get_prodi_detail(j['url_prodi'])
        data_snmptn.append(data)
